# %%
#import libraries
import requests
import json
import pandas as pd

url = r'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/New%20York%20City%2CUSA/2023-12-01/2023-12-31?unitGroup=metric&include=hours&key=T2KQ8BWQR28QEPNZKM3DPZMUY&contentType=json'

#Make a GET request to the API endpoint
response = requests.get(url)

#Parse the JSON response
json_parse = json.loads(response.content)

#Fetch key names
col_name = list(json_parse['days'][0].keys())

#Create a dataframe with column names (keys)
weather_df = pd.DataFrame(json_parse['days'], columns=col_name)
weather_df.head()
# Out:
#      datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0  2023-10-01     1696132800     27.0     16.1  20.8          27.1
# 1  2023-10-02     1696219200     26.6     18.8  21.6          26.6
# 2  2023-10-03     1696305600     27.8     17.1  21.5          28.1
# 3  2023-10-04     1696392000     28.2     18.9  22.3          28.7
# 4  2023-10-05     1696478400     24.4     17.2  20.7          24.4
#
#    feelslikemin  feelslike   dew  humidity  ...   sunrise  sunriseEpoch  \
# 0          16.1       20.8  14.0      67.4  ...  06:52:19    1696157539
# 1          18.8       21.6  14.9      66.7  ...  06:53:20    1696244000
# 2          17.1       21.6  15.3      68.5  ...  06:54:21    1696330461
# 3          18.9       22.4  16.9      72.4  ...  06:55:22    1696416922
# 4          17.2       20.7  15.6      73.5  ...  06:56:24    1696503384
#
#      sunset sunsetEpoch  moonphase  conditions  \
# 0  18:38:34  1696199914       0.57       Clear
# 1  18:36:54  1696286214       0.61       Clear
# 2  18:35:15  1696372515       0.64       Clear
# 3  18:33:37  1696458817       0.67       Clear
# 4  18:31:58  1696545118       0.70       Clear
#
#                             description       icon  \
# 0  Clear conditions throughout the day.  clear-day
# 1  Clear conditions throughout the day.  clear-day
# 2  Clear conditions throughout the day.  clear-day
# 3  Clear conditions throughout the day.  clear-day
# 4  Clear conditions throughout the day.  clear-day
#
#                                             stations  source
# 0  [72505394728, 72055399999, KLGA, KJRB, F1417, ...     obs
# 1  [72505394728, 72055399999, KLGA, KJRB, F1417, ...     obs
# 2  [72505394728, 72055399999, KLGA, KJRB, F1417, ...     obs
# 3  [72505394728, 72055399999, KLGA, KJRB, F1417, ...     obs
# 4  [72505394728, 72055399999, KLGA, KJRB, F1417, ...     obs
#
# [5 rows x 36 columns]

# %%
import requests
import pandas as pd
import json

url = r'https://raw.githubusercontent.com/s-surya-s/IA-Final/main/1_Data/weather_data.txt'

#Make a GET request to the API endpoint
resp = requests.get(url)

#Parse the JSON response
data = json.loads(resp.text)

for day in data['days']:
    print(day['datetime'])
    for hour in day['hours']:
        print(hour['datetime'])


# data['days'][0]['hours']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 11
#       8 resp = requests.get(url)
#      10 #Parse the JSON response
# ---> 11 data = json.loads(resp.text)
#      13 for day in data['days']:
#      14     print(day['datetime'])
#
# File c:\Users\sssur\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\sssur\anaconda3\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 1 column 4 (char 3)
